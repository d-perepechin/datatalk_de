# %%
import pandas as pd
from datetime import datetime
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')
engine.connect()

# %%
query = """
SELECT * FROM pg_catalog.pg_tables
where schemaname <> 'pg_catalog' and schemaname <> 'information_schema'
"""

pd.read_sql(query, con=engine)
# Out:
#   schemaname             tablename tableowner tablespace  hasindexes  \
# 0     public  yellow_tripdata_trip       root       None       False
# 1     public        green_tripdata       root       None       False
# 2     public           zone_lookup       root       None       False
#
#    hasrules  hastriggers  rowsecurity
# 0     False        False        False
# 1     False        False        False
# 2     False        False        False

# %%
query = """
SELECT * FROM green_tripdata
"""

df = pd.read_sql(query, con=engine)
# df = pd.read_csv('https://github.com/DataTalksClub/nyc-tlc-data/releases/download/green/green_tripdata_2019-01.csv.gz')

# %%
query = """
SELECT * FROM zone_lookup
"""

zone_df = pd.read_sql(query, con=engine)
# zone_df = pd.read_csv('https://s3.amazonaws.com/nyc-tlc/misc/taxi+_zone_lookup.csv')

# %%
df.columns
# Out:
# Index(['VendorID', 'lpep_pickup_datetime', 'lpep_dropoff_datetime',
#        'store_and_fwd_flag', 'RatecodeID', 'PULocationID', 'DOLocationID',
#        'passenger_count', 'trip_distance', 'fare_amount', 'extra', 'mta_tax',
#        'tip_amount', 'tolls_amount', 'ehail_fee', 'improvement_surcharge',
#        'total_amount', 'payment_type', 'trip_type', 'congestion_surcharge',
#        'pickupdate', 'dropoffdate'],
#       dtype='object')

# %%
zone_df
# Out:
#      LocationID        Borough                     Zone service_zone
# 0             1            EWR           Newark Airport          EWR
# 1             2         Queens              Jamaica Bay    Boro Zone
# 2             3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3             4      Manhattan            Alphabet City  Yellow Zone
# 4             5  Staten Island            Arden Heights    Boro Zone
# ..          ...            ...                      ...          ...
# 260         261      Manhattan       World Trade Center  Yellow Zone
# 261         262      Manhattan           Yorkville East  Yellow Zone
# 262         263      Manhattan           Yorkville West  Yellow Zone
# 263         264        Unknown                       NV          NaN
# 264         265        Unknown                      NaN          NaN
#
# [265 rows x 4 columns]

# %%
df.shape
# Out:
# (630918, 20)

# %%
df['lpep_pickup_datetime'] = pd.to_datetime(df['lpep_pickup_datetime'])
df['lpep_dropoff_datetime'] = pd.to_datetime(df['lpep_dropoff_datetime'])

# %%
df['pickupdate'] = df.lpep_pickup_datetime.astype("datetime64[D]")
df['dropoffdate'] = df.lpep_dropoff_datetime.astype("datetime64[D]")

# %%
df[(df['passenger_count'].isin([2,3]))&(df.pickupdate == datetime(2019,1,1))].groupby('pickupdate').passenger_count.value_counts()
# Out:
# pickupdate  passenger_count
# 2019-01-01  2                  1282
#             3                   254
# Name: passenger_count, dtype: int64

# %%
df[df['pickupdate'] == datetime(2009,1,1)].groupby('passenger_count').trip_distance.count().sort_values()
# Out:
# passenger_count
# 1    9
# Name: trip_distance, dtype: int64

# %%
df = df.merge(zone_df, left_on='PULocationID', right_on='LocationID', suffixes=('', 'PU_'))
df = df.merge(zone_df, left_on='DOLocationID', right_on='LocationID', suffixes=('', 'DO_'))

# %%
df.head(2)
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2019-01-06 10:00:46   2019-01-06 10:07:18                  N
# 1         2  2019-01-06 10:22:59   2019-01-06 10:29:47                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0           1             7           226                1           1.23
# 1           1             7           226                1           1.52
#
#    fare_amount  ...  pickupdate  dropoffdate  LocationID  Borough     Zone  \
# 0          7.0  ...  2019-01-06   2019-01-06           7   Queens  Astoria
# 1          7.0  ...  2019-01-06   2019-01-06           7   Queens  Astoria
#
#    service_zone  LocationIDDO_  BoroughDO_    ZoneDO_  service_zoneDO_
# 0     Boro Zone            226      Queens  Sunnyside        Boro Zone
# 1     Boro Zone            226      Queens  Sunnyside        Boro Zone
#
# [2 rows x 30 columns]

# %%
df[df['Zone'] == 'Astoria'].sort_values('tip_amount')[['tip_amount', 'ZoneDO_']]
# Out:
#         tip_amount                        ZoneDO_
# 52014        -0.66        Queensbridge/Ravenswood
# 0             0.00                      Sunnyside
# 52309         0.00        Queensbridge/Ravenswood
# 52310         0.00        Queensbridge/Ravenswood
# 52311         0.00        Queensbridge/Ravenswood
# ...            ...                            ...
# 20816        16.47  Long Island City/Queens Plaza
# 169879       25.00                        Jamaica
# 342107       25.00                            NaN
# 154645       30.00                   Central Park
# 21003        88.00  Long Island City/Queens Plaza
#
# [21494 rows x 2 columns]

# %%
df[(df['pickupdate'] == datetime(2019,1,15))&(df['dropoffdate'] == '2019-01-15')] ##
# Out:
#         VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 172684         2  2019-01-15 15:33:43   2019-01-15 15:33:50
# 175421         2  2019-01-15 16:50:12   2019-01-15 17:23:03
# 176753         2  2019-01-15 17:44:00   2019-01-15 18:03:10
# 178806         2  2019-01-15 20:02:24   2019-01-15 20:17:52
# 179998         2  2019-01-15 00:00:45   2019-01-15 00:07:05
# ...          ...                  ...                   ...
# 201222         2  2019-01-15 21:49:49   2019-01-15 21:56:11
# 201223         2  2019-01-15 22:29:47   2019-01-15 22:39:48
# 201258         2  2019-01-15 22:56:18   2019-01-15 23:43:35
# 201411         2  2019-01-15 22:18:09   2019-01-15 22:25:53
# 201517         2  2019-01-15 21:52:54   2019-01-15 21:55:14
#
#        store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 172684                  N           5           195           195
# 175421                  N           1           195            17
# 176753                  N           1            34            52
# 178806                  N           1           195           228
# 179998                  N           1           244            42
# ...                   ...         ...           ...           ...
# 201222                  N           1           129           260
# 201223                  N           1            82           173
# 201258                  N           5            74            55
# 201411                  N           1            82           129
# 201517                  N           1            82           129
#
#         passenger_count  trip_distance  fare_amount  ...  tip_amount  \
# 172684                1           0.00        35.00  ...        0.00
# 175421                1           6.37        25.50  ...        5.46
# 176753                1           2.08        13.00  ...        3.70
# 178806                1           3.23        13.00  ...        0.00
# 179998                2           1.60         7.50  ...        0.00
# ...                 ...            ...          ...  ...         ...
# 201222                1           1.07         6.50  ...        0.00
# 201223                1           1.37         8.00  ...        0.00
# 201258                1          23.42        65.91  ...        0.00
# 201411                1           1.40         7.00  ...        0.00
# 201517                1           0.49         4.00  ...        0.00
#
#         tolls_amount  ehail_fee  improvement_surcharge total_amount  \
# 172684           0.0       None                    0.0        35.00
# 175421           0.0       None                    0.3        32.76
# 176753           0.0       None                    0.3        18.50
# 178806           0.0       None                    0.3        14.30
# 179998           0.0       None                    0.3         8.80
# ...              ...        ...                    ...          ...
# 201222           0.0       None                    0.3         7.80
# 201223           0.0       None                    0.3         9.30
# 201258           0.0       None                    0.0        66.41
# 201411           0.0       None                    0.3         8.30
# 201517           0.0       None                    0.3         5.30
#
#         payment_type  trip_type  congestion_surcharge  pickupdate  dropoffdate
# 172684             1          2                   NaN  2019-01-15   2019-01-15
# 175421             1          1                   NaN  2019-01-15   2019-01-15
# 176753             1          1                   NaN  2019-01-15   2019-01-15
# 178806             2          1                   NaN  2019-01-15   2019-01-15
# 179998             2          1                   NaN  2019-01-15   2019-01-15
# ...              ...        ...                   ...         ...          ...
# 201222             2          1                   NaN  2019-01-15   2019-01-15
# 201223             2          1                   NaN  2019-01-15   2019-01-15
# 201258             1          2                   NaN  2019-01-15   2019-01-15
# 201411             2          1                   NaN  2019-01-15   2019-01-15
# 201517             2          1                   NaN  2019-01-15   2019-01-15
#
# [20530 rows x 22 columns]

# %%
df = pd.read_csv('yellow_tripdata_2021-01.csv.gz', nrows = 100)

# %%
df.shape
# Out:
# (100, 18)

# %%
df.head(1)
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2021-01-01 00:30:10   2021-01-01 00:36:12                1
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            2.1           1                  N           142            43
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0             2          8.0    3.0      0.5         0.0           0.0
#
#    improvement_surcharge  total_amount  congestion_surcharge
# 0                    0.3          11.8                   2.5

# %%
df.to_sql('yellow_tripdata_trip', index=False, con=engine)
# Out:
# 100

# %%
pd.read_sql(query, con=engine)
# Out:
#   schemaname               tablename tableowner tablespace  hasindexes  \
# 0     public    yellow_tripdata_trip       root       None       False
# 1     public  yellow_tripdata_trip_1       root       None       False
#
#    hasrules  hastriggers  rowsecurity
# 0     False        False        False
# 1     False        False        False

# %%
query = """
SELECT * FROM yellow_tripdata_trip_1
"""

pd.read_sql(query, con=engine)
# Out:
#     VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0          1  2021-01-01 00:30:10   2021-01-01 00:36:12                1
# 1          1  2021-01-01 00:51:20   2021-01-01 00:52:19                1
# 2          1  2021-01-01 00:43:30   2021-01-01 01:11:06                1
# 3          1  2021-01-01 00:15:48   2021-01-01 00:31:01                0
# 4          2  2021-01-01 00:31:49   2021-01-01 00:48:21                1
# ..       ...                  ...                   ...              ...
# 95         2  2021-01-01 00:12:41   2021-01-01 00:26:47                1
# 96         2  2021-01-01 00:23:29   2021-01-01 00:35:03                2
# 97         2  2021-01-01 00:46:17   2021-01-01 00:54:25                2
# 98         2  2021-01-01 00:28:16   2021-01-01 00:51:44                1
# 99         2  2021-01-01 00:42:35   2021-01-01 00:54:41                3
#
#     trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            2.10           1                  N           142            43
# 1            0.20           1                  N           238           151
# 2           14.70           1                  N           132           165
# 3           10.60           1                  N           138           132
# 4            4.94           1                  N            68            33
# ..            ...         ...                ...           ...           ...
# 95           4.13           1                  N           161           226
# 96           4.12           1                  N           162            74
# 97           2.22           1                  N           144           170
# 98           7.11           1                  N           264           264
# 99           1.61           1                  N           229           237
#
#     payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0              2          8.0    3.0      0.5        0.00           0.0
# 1              2          3.0    0.5      0.5        0.00           0.0
# 2              1         42.0    0.5      0.5        8.65           0.0
# 3              1         29.0    0.5      0.5        6.05           0.0
# 4              1         16.5    0.5      0.5        4.06           0.0
# ..           ...          ...    ...      ...         ...           ...
# 95             1         14.5    0.5      0.5        3.66           0.0
# 96             2         13.5    0.5      0.5        0.00           0.0
# 97             1          9.0    0.5      0.5        2.56           0.0
# 98             2         23.5    0.5      0.5        0.00           0.0
# 99             2          9.5    0.5      0.5        0.00           0.0
#
#     improvement_surcharge  total_amount  congestion_surcharge
# 0                     0.3         11.80                   2.5
# 1                     0.3          4.30                   0.0
# 2                     0.3         51.95                   0.0
# 3                     0.3         36.35                   0.0
# 4                     0.3         24.36                   2.5
# ..                    ...           ...                   ...
# 95                    0.3         21.96                   2.5
# 96                    0.3         17.30                   2.5
# 97                    0.3         15.36                   2.5
# 98                    0.3         24.80                   0.0
# 99                    0.3         13.30                   2.5
#
# [100 rows x 18 columns]

# %%
# Out:
# 0

# %%
query = """
SELECT count(*) FROM yellow_tripdata_trip
"""

pd.read_sql(query, con=engine)
# Out:
#    count
# 0      0

# %%
df_iter = pd.read_csv('yellow_tripdata_2021-01.csv.gz', chunksize=100_000)

# %%
df = next(df_iter)
df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)

# %%
df.head(0).to_sql('yellow_tripdata_trip', index=False, con=engine, if_exists='replace')
# Out:
# 0

# %%
print(pd.io.sql.get_schema(df, 'yellow_tripdata_trip', con=engine))
# Out:
# CREATE TABLE yellow_tripdata_trip (
# 	"VendorID" BIGINT,
# 	tpep_pickup_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	tpep_dropoff_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	passenger_count BIGINT,
# 	trip_distance FLOAT(53),
# 	"RatecodeID" BIGINT,
# 	store_and_fwd_flag TEXT,
# 	"PULocationID" BIGINT,
# 	"DOLocationID" BIGINT,
# 	payment_type BIGINT,
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	congestion_surcharge FLOAT(53)
# )

# %%
query = """
SELECT count(*) FROM yellow_tripdata_trip
"""

pd.read_sql(query, con=engine)
# Out:
#    count
# 0      0

# %%
while True:
    df = next(df_iter)
    df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
    df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)
    
    df.to_sql('yellow_tripdata_trip', index=False, con=engine, if_exists='append')
    
    print('inserting...')
# Out:
# inserting...
# inserting...
# inserting...
# inserting...
# inserting...
# inserting...
# inserting...
# inserting...
# inserting...
# inserting...
# inserting...
# C:\Users\daper\AppData\Local\Temp\ipykernel_27880\4002462225.py:2: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = next(df_iter)
# inserting...
# inserting...
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27880\4002462225.py in <module>
#       1 while True:
# ----> 2     df = next(df_iter)
#       3     df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
#       4     df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)
#       5
#
# C:\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in __next__(self)
#    1184     def __next__(self):
#    1185         try:
# -> 1186             return self.get_chunk()
#    1187         except StopIteration:
#    1188             self.close()
#
# C:\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in get_chunk(self, size)
#    1281                 raise StopIteration
#    1282             size = min(size, self.nrows - self._currow)
# -> 1283         return self.read(nrows=size)
#    1284
#    1285     def __enter__(self):
#
# C:\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in read(self, nrows)
#    1251             nrows = validate_integer("nrows", nrows)
#    1252             try:
# -> 1253                 index, columns, col_dict = self._engine.read(nrows)
#    1254             except Exception:
#    1255                 self.close()
#
# C:\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py in read(self, nrows)
#     223         try:
#     224             if self.low_memory:
# --> 225                 chunks = self._reader.read_low_memory(nrows)
#     226                 # destructive to chunks
#     227                 data = _concatenate_chunks(chunks)
#
# C:\anaconda3\lib\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.read_low_memory()
#
# StopIteration:

# %%
pd.read_sql(query, con=engine)
# Out:
#      count
# 0  1269765

# %%
df.head(1)
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 1300000       NaN  2021-01-05 10:38:40   2021-01-05 10:46:20              NaN
#
#          trip_distance  RatecodeID  store_and_fwd_flag  PULocationID  \
# 1300000            1.3         NaN                 NaN           170
#
#          DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# 1300000           161           NaN          7.0    0.0      0.5        1.03
#
#          tolls_amount  improvement_surcharge  total_amount  \
# 1300000           0.0                    0.3         11.33
#
#          congestion_surcharge
# 1300000                   2.5

# %%
query = """
SELECT max(tpep_pickup_datetime), min(tpep_pickup_datetime), max(total_amount) FROM yellow_tripdata_trip
"""

pd.read_sql(query, con=engine)
# Out:
#                   max                 min      max
# 0 2021-02-22 16:52:16 2008-12-31 23:05:14  7661.28
